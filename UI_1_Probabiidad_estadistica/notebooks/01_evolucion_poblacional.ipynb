# %% [markdown]
# # Práctica 1.1 — Probabilidad y Estadística
# ## Actividad 1 — Identificación de la fuente
# ### Análisis de la evolución poblacional anual
#
# **CIta**
# > UN, World Population Prospects (2024) – processed by Our World in Data. “Annual change in population – UN WPP” [dataset]. United Nations, “World Population Prospects”; United Nations, “World Population Prospects - Interim Update” [original data].
#
# **Preguntas**
#
# Responde brevemente:
#
# 1. ¿Quién produjo originalmente los datos? United Nations
#
# 2. ¿Qué organización los procesa para su utilización en Our World in Data? Our World in Data
#
# 3. ¿Qué representa la variable que analizarás? Annual population growth

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\5TO SEMESTRE PROYECTOS\\TÓPICOS DE BIG DATA\\UI_1_Probabiidad_estadistica\\data\\raw\\annual-population-growth\\annual-population-growth.csv")
df
# Out:
#             Entity Code  Year  Annual change in population  \
# 0      Afghanistan  AFG  1951                     103163.0
# 1      Afghanistan  AFG  1952                     108441.0
# 2      Afghanistan  AFG  1953                     108919.0
# 3      Afghanistan  AFG  1954                     111251.0
# 4      Afghanistan  AFG  1955                     119027.0
# ...            ...  ...   ...                          ...
# 38395     Zimbabwe  ZWE  2096                          NaN
# 38396     Zimbabwe  ZWE  2097                          NaN
# 38397     Zimbabwe  ZWE  2098                          NaN
# 38398     Zimbabwe  ZWE  2099                          NaN
# 38399     Zimbabwe  ZWE  2100                          NaN
#
#        Annual population change (Projected)
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# ...

# %%
df.head()
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
# 4  Afghanistan  AFG  1955                     119027.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
df.shape
# Out:
# (38400, 5)

# %%
df.columns.tolist()
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Annual change in population',
#  'Annual population change (Projected)']

# %%
df.dtypes
# Out:
# Entity                                      str
# Code                                        str
# Year                                      int64
# Annual change in population             float64
# Annual population change (Projected)    float64
# dtype: object

# %%
df.describe()
# Out:
#                Year  Annual change in population  \
# count  38400.000000                 1.868800e+04
# mean    2025.500000                 2.063019e+06
# std       43.300872                 9.440859e+06
# min     1951.000000                -3.315935e+06
# 25%     1988.000000                 1.781000e+03
# 50%     2025.500000                 4.689800e+04
# 75%     2063.000000                 3.021128e+05
# max     2100.000000                 9.337137e+07
#
#        Annual population change (Projected)
# count                          1.971200e+04
# mean                           8.375481e+05
# std                            5.816745e+06
# min                           -2.291035e+07
# 25%                           -9.742750e+03
# 50%                            9.350000e+01
# 75%                            1.411160e+05
# max                            7.206736e+07

# %%
df.isnull().sum()
# Out:
# Entity                                      0
# Code                                     1200
# Year                                        0
# Annual change in population             19712
# Annual population change (Projected)    18688
# dtype: int64

# %%
df["Entity"].nunique()
# Out:
# 256

# %%
df_exxtraccion_entity = df[["Entity", "Year"]]
df_exxtraccion_entity.shape
# df_exxtraccion_entity.head(3)
# Out:
# (38400, 2)

# %%
df_2020 = df[df["Year"] == 2020]
df_2020.head(3)
# Out:
#           Entity    Code  Year  Annual change in population  \
# 69   Afghanistan     AFG  2020                    1212852.0
# 219  Africa (UN)  UN_AFR  2020                   32815675.0
# 369      Albania     ALB  2020                     -13061.0
#
#      Annual population change (Projected)
# 69                                    NaN
# 219                                   NaN
# 369                                   NaN

# %%
df_2020_ext_col1 = df_2020[["Entity", "Year"]]
df_2020_ext_col1.head(3)
df_2020_ext_col2 = df[df["Year"] == 2020][["Entity", "Year"]]
df_2020_ext_col2.head(3)
# Out:
#           Entity  Year
# 69   Afghanistan  2020
# 219  Africa (UN)  2020
# 369      Albania  2020

# %%
df_2005_2020 = df[(df["Year"] >= 2005) & (df["Year"] <= 2020) & (df["Entity"] == "Mexico")]
df_2005_2020.shape
# Out:
# (16, 5)

# %%
df_2005_2020.head(3)
# Out:
#        Entity Code  Year  Annual change in population  \
# 22254  Mexico  MEX  2005                    1417373.0
# 22255  Mexico  MEX  2006                    1442162.0
# 22256  Mexico  MEX  2007                    1520690.0
#
#        Annual population change (Projected)
# 22254                                   NaN
# 22255                                   NaN
# 22256                                   NaN

# %%
df_ext_EA = df_2005_2020[["Entity", "Annual change in population"]]
df_ext_EA.head(3)
# Out:
#        Entity  Annual change in population
# 22254  Mexico                    1417373.0
# 22255  Mexico                    1442162.0
# 22256  Mexico                    1520690.0

# %%
dfC = df[df["Entity"].str.startswith("C")]
dfCPaises = dfC["Entity"].unique()
dfCPaises
# Out:
# <StringArray>
# [                'Cambodia',                 'Cameroon',
#                    'Canada',               'Cape Verde',
#            'Cayman Islands', 'Central African Republic',
#                      'Chad',                    'Chile',
#                     'China',                 'Colombia',
#                   'Comoros',                    'Congo',
#              'Cook Islands',               'Costa Rica',
#             'Cote d'Ivoire',                  'Croatia',
#                      'Cuba',                  'Curacao',
#                    'Cyprus',                  'Czechia']
# Length: 20, dtype: str

# %%
dfFiltroC = df[(df["Entity"] == "China") & (df["Year"] >= 1983) & (df["Year"] <= 2021)]
dfFiltroC
# Out:
#      Entity Code  Year  Annual change in population  \
# 6782  China  CHN  1983                   15476775.0
# 6783  China  CHN  1984                   14784693.0
# 6784  China  CHN  1985                   15958173.0
# 6785  China  CHN  1986                   17425789.0
# 6786  China  CHN  1987                   18983838.0
# 6787  China  CHN  1988                   19026723.0
# 6788  China  CHN  1989                   18746838.0
# 6789  China  CHN  1990                   19591719.0
# 6790  China  CHN  1991                   17205808.0
# 6791  China  CHN  1992                   13785703.0
# 6792  China  CHN  1993                   12734338.0
# 6793  China  CHN  1994                   11694525.0
# 6794  China  CHN  1995                   11130830.0
# 6795  China  CHN  1996                   10810880.0
# 6796  China  CHN  1997                   10194814.0
# 6797  China  CHN  1998                    9707499.0
# 6798  China  CHN  1999                    9329528.0
# ...

# %%
dfFiltroC.mean(numeric_only=True)
# Out:
# Year                                    2.002000e+03
# Annual change in population             1.058587e+07
# Annual population change (Projected)             NaN
# dtype: float64

# %%
dfFiltroC.median(numeric_only=True)
# Out:
# Year                                       2002.0
# Annual change in population             9270208.0
# Annual population change (Projected)          NaN
# dtype: float64

# %%
dfFiltroC.var(numeric_only=True)
# Out:
# Year                                    1.300000e+02
# Annual change in population             2.051512e+13
# Annual population change (Projected)             NaN
# dtype: float64

# %%
dfFiltroC.std(numeric_only=True)
# Out:
# Year                                    1.140175e+01
# Annual change in population             4.529362e+06
# Annual population change (Projected)             NaN
# dtype: float64

# %%
dfFiltroC.min(numeric_only=True)
# Out:
# Year                                      1983.0
# Annual change in population             331176.0
# Annual population change (Projected)         NaN
# dtype: float64

# %%
dfFiltroC.max(numeric_only=True)
# Out:
# Year                                        2021.0
# Annual change in population             19591719.0
# Annual population change (Projected)           NaN
# dtype: float64

# %%
df.head()
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
# 4  Afghanistan  AFG  1955                     119027.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
df.loc[:, "Entity"]
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 38395       Zimbabwe
# 38396       Zimbabwe
# 38397       Zimbabwe
# 38398       Zimbabwe
# 38399       Zimbabwe
# Name: Entity, Length: 38400, dtype: str

# %%
df.iloc[:, [0,2]]
# Out:
#             Entity  Year
# 0      Afghanistan  1951
# 1      Afghanistan  1952
# 2      Afghanistan  1953
# 3      Afghanistan  1954
# 4      Afghanistan  1955
# ...            ...   ...
# 38395     Zimbabwe  2096
# 38396     Zimbabwe  2097
# 38397     Zimbabwe  2098
# 38398     Zimbabwe  2099
# 38399     Zimbabwe  2100
#
# [38400 rows x 2 columns]

# %%
df.iloc[600:610, 0:2]
# Out:
#              Entity Code
# 600  American Samoa  ASM
# 601  American Samoa  ASM
# 602  American Samoa  ASM
# 603  American Samoa  ASM
# 604  American Samoa  ASM
# 605  American Samoa  ASM
# 606  American Samoa  ASM
# 607  American Samoa  ASM
# 608  American Samoa  ASM
# 609  American Samoa  ASM

# %% [markdown]
# # Ejercicios loc iloc

# %%
df.loc[10000]
# Out:
# Entity                                  Equatorial Guinea
# Code                                                  GNQ
# Year                                                 2051
# Annual change in population                           NaN
# Annual population change (Projected)              46407.0
# Name: 10000, dtype: object

# %%
df.iloc[10000]
# Out:
# Entity                                  Equatorial Guinea
# Code                                                  GNQ
# Year                                                 2051
# Annual change in population                           NaN
# Annual population change (Projected)              46407.0
# Name: 10000, dtype: object

# %%
df.loc[:, ["Entity", "Year", "Annual change in population"]]
# Out:
#             Entity  Year  Annual change in population
# 0      Afghanistan  1951                     103163.0
# 1      Afghanistan  1952                     108441.0
# 2      Afghanistan  1953                     108919.0
# 3      Afghanistan  1954                     111251.0
# 4      Afghanistan  1955                     119027.0
# ...            ...   ...                          ...
# 38395     Zimbabwe  2096                          NaN
# 38396     Zimbabwe  2097                          NaN
# 38397     Zimbabwe  2098                          NaN
# 38398     Zimbabwe  2099                          NaN
# 38399     Zimbabwe  2100                          NaN
#
# [38400 rows x 3 columns]

# %%
df.iloc[:, [0,2,3]]
# Out:
#             Entity  Year  Annual change in population
# 0      Afghanistan  1951                     103163.0
# 1      Afghanistan  1952                     108441.0
# 2      Afghanistan  1953                     108919.0
# 3      Afghanistan  1954                     111251.0
# 4      Afghanistan  1955                     119027.0
# ...            ...   ...                          ...
# 38395     Zimbabwe  2096                          NaN
# 38396     Zimbabwe  2097                          NaN
# 38397     Zimbabwe  2098                          NaN
# 38398     Zimbabwe  2099                          NaN
# 38399     Zimbabwe  2100                          NaN
#
# [38400 rows x 3 columns]

# %%
df.loc[10000, ["Entity", "Year", "Annual change in population"]]
# Out:
# Entity                         Equatorial Guinea
# Year                                        2051
# Annual change in population                  NaN
# Name: 10000, dtype: object

# %%
df.iloc[10000, [0, 2, 3]]
# Out:
# Entity                         Equatorial Guinea
# Year                                        2051
# Annual change in population                  NaN
# Name: 10000, dtype: object

# %%
df.loc[(df["Year"] == 2020) & (df["Entity"] == "Mexico")]
# Out:
#        Entity Code  Year  Annual change in population  \
# 22269  Mexico  MEX  2020                    1036075.0
#
#        Annual population change (Projected)
# 22269                                   NaN

# %%
df.iloc[]
